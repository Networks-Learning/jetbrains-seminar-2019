# %%
# %matplotlib inline

# %%
# %run -i simPointProcess.py
# Out:
# ECOS 2.0.4 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -8.459e+01  +1e+03  7e-01  1e-01  1e+00  1e+00    ---    ---    0  0  - |  -  -
#  1  -2.321e+01  -7.407e+01  +4e+02  5e-01  8e-02  7e-01  4e-01  0.6266  1e-01   1  1  1 |  2  2
#  2  +4.422e+01  +1.563e+01  +2e+02  3e-01  4e-02  4e-01  2e-01  0.9791  5e-01   1  1  1 |  7  0
#  3  +9.890e+01  +9.198e+01  +5e+01  9e-02  1e-02  1e-01  5e-02  0.7833  9e-03   1  1  1 |  1  1
#  4  +1.271e+02  +1.254e+02  +1e+01  2e-02  3e-03  2e-02  1e-02  0.7833  9e-03   1  1  1 |  1  1
#  5  +1.287e+02  +1.284e+02  +2e+00  5e-03  6e-04  6e-03  2e-03  0.7833  2e-02   1  1  1 |  1  1
#  6  +1.301e+02  +1.300e+02  +6e-01  1e-03  1e-04  2e-03  6e-04  0.7833  5e-02   1  1  1 |  2  1
#  7  +1.302e+02  +1.302e+02  +1e-01  4e-04  4e-05  4e-04  1e-04  0.7833  5e-02   1  1  1 |  2  1
# ...

# %%
print('alpha_opt = {}, alpha_true = {}'.format(alpha_opt.value, alpha_0))
# Out:
# alpha_opt = 0.5836763317912126, alpha_true = 0.5

# %%
print('lambda_opt = {}, lambda_true = {}'.format(lambda_opt.value, lambda_0))
# Out:
# lambda_opt = 0.7685049324377323, lambda_true = 1
